# %% [markdown]
# # 120 Years of Olympics Data
#
# This data set was taken from kagggle and contains 120 years of info about Olympic athletes. We used this data set to practice some hypothesis testing. The data can be found here:
#
# https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results

# %%
# Libraries
import numpy as np
import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline

# %%
# load the dataframe and check it out with pandas-profiling
df = pd.read_csv('athlete_events.csv')
profile = pandas_profiling.ProfileReport(df)
profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>15 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>271116 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>8.9% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>31.0 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>120.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>10 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Age"><code>Age</code></a> has 9474 / 3.5% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Event"><code>Event</code></a> has a high cardinality: 765 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Games"><code>Games</code></a> has a high cardinality: 51 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Height"><code>Height</code></a> has 60171 / 22.2% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Medal"><code>Medal</code></a> has 231333 / 85.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_NOC"><code>NOC</code></a> has a high cardinality: 230 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Name"><code>Name</code></a> has a high cardinality: 134732 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Sport"><code>Sport</code></a> has a high cardinality: 66 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Team"><code>Team</code></a> has a high cardinality: 1184 dis

# %%
# There are misnamed teams- for example two teams named Russia and Russia1, France and France1, etc. To fix
# this, another csv provided by kaggle contains a column called region that will name the country appropriately
# Merging that to our current dataframe.
noc_regions = pd.read_csv('noc_regions.csv')
df = df.merge(noc_regions, on='NOC')

# %%
# Since we want to explore BMI, we have to handle the missing data within these fields
# We elected to drop them as we think this won't bias the distribution as much as alternative 
# ways of handling it. We decided to do age as well to observe the age distribution later

bmi_df = df.dropna(subset = ['Age', 'Height', 'Weight'])

profile = pandas_profiling.ProfileReport(bmi_df)
profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>18 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>205911 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>10.2% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>28.3 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>144.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>12 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Event"><code>Event</code></a> has a high cardinality: 590 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Games"><code>Games</code></a> has a high cardinality: 51 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Medal"><code>Medal</code></a> has 175739 / 85.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_NOC"><code>NOC</code></a> has a high cardinality: 225 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Name"><code>Name</code></a> has a high cardinality: 98445 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Sport"><code>Sport</code></a> has a high cardinality: 56 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Team"><code>Team</code></a> has a high cardinality: 655 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_notes"><code>notes</code></a> has 202418 / 98.3% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_region"><code>region</code></a> has a high ca

# %% [markdown]
# # Have Atheletes physically changed over time? BMI as measure
# Looking at populations of athletes between the years 1900-1916 to compare to the populations of 2000-2016 to see if BMI has changed. Grabbing the relevant data

# %%
# Making a BMI column
# Converting weight to lbs from kg.
# Want a df with height in inches, weight in lbs and a BMI

# Making backup copies of working df
bmi_df_copy = bmi_df.copy()


# First working on BMI

# Converting height to meters for BMI calculation
bmi_df_copy['Height'] = bmi_df_copy['Height']/100

# Making the BMI column
bmi_df_copy['BMI'] = bmi_df_copy['Weight']/(bmi_df_copy['Height']**2)

# Convert weight to lbs
bmi_df_copy['Weight'] = round(bmi_df_copy['Weight']*2.20462,1)

# Converting cm to inches
bmi_df_copy['Height'] = round(bmi_df_copy['Height']*100*0.393701,1)

bmi_df_copy # looks good
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 0            1                          A Dijiang   M  24.0    70.9   176.4
# 1            2                           A Lamusi   M  23.0    66.9   132.3
# 2          602                      Abudoureheman   M  22.0    71.7   165.3
# 3         1463                          Ai Linuer   M  25.0    63.0   136.7
# 4         1464                          Ai Yanhan   F  14.0    66.1   119.0
# 5         1464                          Ai Yanhan   F  14.0    66.1   119.0
# 6         3605                        An Weijiang   M  22.0    70.1   158.7
# 7         3605                        An Weijiang   M  22.0    70.1   158.7
# 8         3610                          An Yulong   M  19.0    68.1   154.3
# 9         3610                          An Yulong   M  19.0    68.1   154.3
# 10        3610                          An Yulong   M  19.0    68.1   154.3
# 11        3610                          An Yulong   M  23.0    68.1   154.3
# 12        3611                        An Zhongxin   F  23.0    66.9   143.3
# 13        3611                        An Zhongxin   F  27.0    66.9   143.3
# 14        4639                       Ao Changrong   M  25.0    68.1   156.5
# 15        4641                           Ao Tegen   M  21.0    71.3   198.4
# 16        6376                           Ba Dexin   M  23.0    72.8   176.4
# 17        6381                             Ba Yan   F  21.0    72.0   172.0
# 18        6382                        Ba Yanchuan   M  24.0    73.6   220.5
# 19        6383                        Ba Yongshan   M  22.0    70.9   154.3
# 20        6847                           Bai Anqi   F  19.0    64.6   130.1
# 21        6848                     Bai Chongguang   M  21.0    72.4   183.0
# 22        6849                         Bai Faquan   M  26.0    68.1   145.5
# 23        6849                         Bai Faquan   M  30.0    68.1   145.5
# 24        6851                            Bai Jie   F  28.0    64.2   116.8
# 25        6853                           Bai Lili   F  25.0    66.1   125.7
# 26        6854                            Bai Mei   F  17.0    65.4   101.4
# 27        6855                        Bai Qiuming   M  19.0    68.1   154.3
# 28        6857                            Bai Xue   F  19.0    65.0   116.8
# 29        7595                        Bao Chunlai   M  21.0    74.8   176.4
# ...        ...                                ...  ..   ...     ...     ...
# 270726   81401                    Ncholu Monontsi   M  25.0    69.7   156.5
# 270727   81698                    Motsapi Moorosi   M  27.0    66.9   136.7
# 270728   81698                    Motsapi Moorosi   M  27.0    66.9   136.7
# 270729   81710               Thabiso Paul Moqhali   M  24.0    66.1   108.0
# 270730   81710               Thabiso Paul Moqhali   M  32.0    66.1   108.0
# 270731   82194                  Mpho Jonas Morobe   M  29.0    67.7   132.3
# 270732   82194                  Mpho Jonas Morobe   M  29.0    67.7   132.3
# 270733   82490             Moses Moeketsi Mosuhli   M  27.0    62.6   136.7
# 270734   84444                       Tello Namane   M  18.0    70.1   110.2
# 270738   87277                       Frans Ntaole   M  33.0    66.1   136.7
# 270739   87277                       Frans Ntaole   M  33.0    66.1   136.7
# 270740   87282                       Noheku Nteso   M  26.0    59.8    97.0
# 270741   87288                 Mpesela Ntlot'soeu   M  27.0    60.6   127.9
# 270742   95244  Mantokoane Angelina Pitso Sephooa   F  17.0    58.3    99.2
# 270743   95244  Mantokoane Angelina Pitso Sephooa   F  17.0    58.3    99.2
# 270744   98490        Gabashane Vincent Rakabaele   M  31.0    64.2   119.0
# 270745   98490        Gabashane Vincent Rakabaele   M  35.0    64.2   119.0
# 270746   98536                Thabisio Ralekhetla   M  36.0    67.7   119.0
# 270747   98555                       Patrick Rama   M  27.0    65.0   143.3
# 270748   98690          Tsepo Ramonene-Mathibelle   M  21.0    67.3   119.0
# 270749   98690          Tsepo Ramonene-Mathibelle   M  25.0    67.3   119.0
# 270751  108485                    Sebongile Sello   F  20.0    62.2    90.4
# 270753  109447                     Bothloko Shebe   M  20.0    70.1   143.3
# 270754  109447                     Bothloko Shebe   M  20.0    70.1   143.3
# 270759  119456                Motlalepula Thabana   M  30.0    60.2   119.0
# 270760  119487             Likeleli Alinah Thamae   F  22.0    66.9   108.0
# 270762  120575                    Mamorallo Tjoka   F  23.0    59.1   123.5
# 270763  120575                    Mamorallo Tjoka   F  27.0    59.1   123.5
# 270765  122215                         Lefa Tsapi   M  23.0    66.9   138.9
# 270766  122299                      Mosolesa Tsie   M  20.0    68.9   165.3
#
#            Team  NOC        Games  Year  Season            City  \
# 0         China  CHN  1992 Summer  1992  Summer       Barcelona
# 1         China  CHN  2012 Summer  2012  Summer          London
# 2         China  CHN  2000 Summer  2000  Summer          Sydney
# 3         China  CHN  2004 Summer  2004  Summer          Athina
# 4         China  CHN  2016 Summer  2016  Summer  Rio de Janeiro
# 5         China  CHN  2016 Summer  2016  Summer  Rio de Janeiro
# 6         China  CHN  2006 Winter  2006  Winter          Torino
# 7         China  CHN  2006 Winter  2006  Winter          Torino
# 8         China  CHN  1998 Winter  1998  Winter          Nagano
# 9         China  CHN  1998 Winter  1998  Winter          Nagano
# 10        China  CHN  1998 Winter  1998  Winter          Nagano
# 11        China  CHN  2002 Winter  2002  Winter  Salt Lake City
# 12        China  CHN  1996 Summer  1996  Summer         Atlanta
# 13        China  CHN  2000 Summer  2000  Summer          Sydney
# 14        China  CHN  2008 Summer  2008  Summer         Beijing
# 15        China  CHN  1996 Summer  1996  Summer         Atlanta
# 16        China  CHN  2014 Winter  2014  Winter           Sochi
# 17        China  CHN  1984 Summer  1984  Summer     Los Angeles
# 18        China  CHN  1996 Summer  1996  Summer         Atlanta
# 19        China  CHN  1984 Summer  1984  Summer     Los Angeles
# 20        China  CHN  2012 Summer  2012  Summer          London
# 21        China  CHN  1992 Summer  1992  Summer       Barcelona
# 22        China  CHN  2012 Summer  2012  Summer          London
# 23        China  CHN  2016 Summer  2016  Summer  Rio de Janeiro
# 24        China  CHN  2000 Summer  2000  Summer          Sydney
# 25        China  CHN  2004 Summer  2004  Summer          Athina
# 26        China  CHN  1992 Summer  1992  Summer       Barcelona
# 27        China  CHN  2014 Winter  2014  Winter           Sochi
# 28        China  CHN  2008 Summer  2008  Summer         Beijing
# 29        China  CHN  2004 Summer  2004  Summer          Athina
# ...         ...  ...          ...   ...     ...             ...
# 270726  Lesotho  LES  1988 Summer  1988  Summer           Seoul
# 270727  Lesotho  LES  1972 Summer  1972  Summer          Munich
# 270728  Lesotho  LES  1972 Summer  1972  Summer          Munich
# 270729  Lesotho  LES  1992 Summer  1992  Summer       Barcelona
# 270730  Lesotho  LES  2000 Summer  2000  Summer          Sydney
# 270731  Lesotho  LES  1996 Summer  1996  Summer         Atlanta
# 270732  Lesotho  LES  1996 Summer  1996  Summer         Atlanta
# 270733  Lesotho  LES  2008 Summer  2008  Summer         Beijing
# 270734  Lesotho  LES  1992 Summer  1992  Summer       Barcelona
# 270738  Lesotho  LES  1984 Summer  1984  Summer     Los Angeles
# 270739  Lesotho  LES  1984 Summer  1984  Summer     Los Angeles
# 270740  Lesotho  LES  1988 Summer  1988  Summer           Seoul
# 270741  Lesotho  LES  2004 Summer  2004  Summer          Athina
# 270742  Lesotho  LES  1992 Summer  1992  Summer       Barcelona
# 270743  Lesotho  LES  1992 Summer  1992  Summer       Barcelona
# 270744  Lesotho  LES  1980 Summer  1980  Summer          Moskva
# 270745  Lesotho  LES  1984 Summer  1984  Summer     Los Angeles
# 270746  Lesotho  LES  1996 Summer  1996  Summer         Atlanta
# 270747  Lesotho  LES  1992 Summer  1992  Summer       Barcelona
# 270748  Lesotho  LES  2012 Summer  2012  Summer          London
# 270749  Lesotho  LES  2016 Summer  2016  Summer  Rio de Janeiro
# 270751  Lesotho  LES  1996 Summer  1996  Summer         Atlanta
# 270753  Lesotho  LES  1992 Summer  1992  Summer       Barcelona
# 270754  Lesotho  LES  1992 Summer  1992  Summer       Barcelona
# 270759  Lesotho  LES  1980 Summer  1980  Summer          Moskva
# 270760  Lesotho  LES  2000 Summer  2000  Summer          Sydney
# 270762  Lesotho  LES  2008 Summer  2008  Summer         Beijing
# 270763  Lesotho  LES  2012 Summer  2012  Summer          London
# 270765  Lesotho  LES  1984 Summer  1984  Summer     Los Angeles
# 270766  Lesotho  LES  2000 Summer  2000  Summer          Sydney
#
#                             Sport  \
# 0                      Basketball
# 1                            Judo
# 2                          Boxing
# 3                       Wrestling
# 4                        Swimming
# 5                        Swimming
# 6                   Speed Skating
# 7                   Speed Skating
# 8       Short Track Speed Skating
# 9       Short Track Speed Skating
# 10      Short Track Speed Skating
# 11      Short Track Speed Skating
# 12                       Softball
# 13                       Softball
# 14                         Hockey
# 15                           Judo
# 16                        Curling
# 17                     Basketball
# 18                      Wrestling
# 19                        Archery
# 20                       Swimming
# 21                         Boxing
# 22                      Triathlon
# 23                      Triathlon
# 24                       Football
# 25                       Football
# 26            Rhythmic Gymnastics
# 27                  Speed Skating
# 28                      Athletics
# 29                      Badminton
# ...                           ...
# 270726                     Boxing
# 270727                  Athletics
# 270728                  Athletics
# 270729                  Athletics
# 270730                  Athletics
# 270731                  Athletics
# 270732                  Athletics
# 270733                  Athletics
# 270734                  Athletics
# 270738                  Athletics
# 270739                  Athletics
# 270740                  Athletics
# 270741                  Athletics
# 270742                  Athletics
# 270743                  Athletics
# 270744                  Athletics
# 270745                  Athletics
# 270746                  Athletics
# 270747                  Athletics
# 270748                  Athletics
# 270749                  Athletics
# 270751                  Athletics
# 270753                  Athletics
# 270754                  Athletics
# 270759                  Athletics
# 270760                  Taekwondo
# 270762                  Athletics
# 270763                  Athletics
# 270765                     Boxing
# 270766                     Boxing
#
#                                                     Event   Medal   region  \
# 0                             Basketball Men's Basketball     NaN    China
# 1                            Judo Men's Extra-Lightweight     NaN    China
# 2                               Boxing Men's Middleweight     NaN    China
# 3                Wrestling Men's Lightweight, Greco-Roman     NaN    China
# 4                   Swimming Women's 200 metres Freestyle     NaN    China
# 5         Swimming Women's 4 x 200 metres Freestyle Relay     NaN    China
# 6                          Speed Skating Men's 500 metres     NaN    China
# 7                        Speed Skating Men's 1,000 metres     NaN    China
# 8              Short Track Speed Skating Men's 500 metres  Silver    China
# 9            Short Track Speed Skating Men's 1,000 metres     NaN    China
# 10      Short Track Speed Skating Men's 5,000 metres R...  Bronze    China
# 11      Short Track Speed Skating Men's 5,000 metres R...  Bronze    China
# 12                              Softball Women's Softball  Silver    China
# 13                              Softball Women's Softball     NaN    China
# 14                                    Hockey Men's Hockey     NaN    China
# 15                                Judo Men's Middleweight     NaN    China
# 16                                  Curling Men's Curling     NaN    China
# 17                          Basketball Women's Basketball  Bronze    China
# 18               Wrestling Men's Heavyweight, Greco-Roman     NaN    China
# 19                               Archery Men's Individual     NaN    China
# 20                 Swimming Women's 200 metres Backstroke     NaN    China
# 21                         Boxing Men's Light-Heavyweight     NaN    China
# 22                       Triathlon Men's Olympic Distance     NaN    China
# 23                       Triathlon Men's Olympic Distance     NaN    China
# 24                              Football Women's Football     NaN    China
# 25                              Football Women's Football     NaN    China
# 26                 Rhythmic Gymnastics Women's Individual     NaN    China
# 27                         Speed Skating Men's 500 metres     NaN    China
# 28                        Athletics Women's 10,000 metres     NaN    China
# 29                                Badminton Men's Singles     NaN    China
# ...                                                   ...     ...      ...
# 270726                    Boxing Men's Light-Middleweight     NaN  Lesotho
# 270727                         Athletics Men's 100 metres     NaN  Lesotho
# 270728                         Athletics Men's 200 metres     NaN  Lesotho
# 270729                           Athletics Men's Marathon     NaN  Lesotho
# 270730                           Athletics Men's Marathon     NaN  Lesotho
# 270731                         Athletics Men's 400 metres     NaN  Lesotho
# 270732               Athletics Men's 4 x 400 metres Relay     NaN  Lesotho
# 270733                           Athletics Men's Marathon     NaN  Lesotho
# 270734                       Athletics Men's 5,000 metres     NaN  Lesotho
# 270738                      Athletics Men's 10,000 metres     NaN  Lesotho
# 270739                           Athletics Men's Marathon     NaN  Lesotho
# 270740                           Athletics Men's Marathon     NaN  Lesotho
# 270741                           Athletics Men's Marathon     NaN  Lesotho
# 270742                       Athletics Women's 800 metres     NaN  Lesotho
# 270743                     Athletics Women's 1,500 metres     NaN  Lesotho
# 270744                           Athletics Men's Marathon     NaN  Lesotho
# 270745                           Athletics Men's Marathon     NaN  Lesotho
# 270746                           Athletics Men's Marathon     NaN  Lesotho
# 270747                      Athletics Men's 10,000 metres     NaN  Lesotho
# 270748                           Athletics Men's Marathon     NaN  Lesotho
# 270749                           Athletics Men's Marathon     NaN  Lesotho
# 270751             Athletics Women's 4 x 100 metres Relay     NaN  Lesotho
# 270753                         Athletics Men's 100 metres     NaN  Lesotho
# 270754                         Athletics Men's 200 metres     NaN  Lesotho
# 270759                      Athletics Men's 10,000 metres     NaN  Lesotho
# 270760                        Taekwondo Women's Flyweight     NaN  Lesotho
# 270762                         Athletics Women's Marathon     NaN  Lesotho
# 270763                         Athletics Women's Marathon     NaN  Lesotho
# 270765                          Boxing Men's Welterweight     NaN  Lesotho
# 270766                          Boxing Men's Welterweight     NaN  Lesotho
#
#        notes        BMI
# 0        NaN  24.691358
# 1        NaN  20.761246
# 2        NaN  22.642193
# 3        NaN  24.218750
# 4        NaN  19.132653
# 5        NaN  19.132653
# 6        NaN  22.724403
# 7        NaN  22.724403
# 8        NaN  23.388687
# 9        NaN  23.388687
# 10       NaN  23.388687
# 11       NaN  23.388687
# 12       NaN  22.491349
# 13       NaN  22.491349
# 14       NaN  23.722811
# 15       NaN  27.471689
# 16       NaN  23.374726
# 17       NaN  23.291230
# 18       NaN  28.596757
# 19       NaN  21.604938
# 20       NaN  21.936347
# 21       NaN  24.515595
# 22       NaN  22.052190
# 23       NaN  22.052190
# 24       NaN  19.948060
# 25       NaN  20.195578
# 26       NaN  16.693279
# 27       NaN  23.388687
# 28       NaN  19.467401
# 29       NaN  22.160665
# ...      ...        ...
# 270726   NaN  22.662709
# 270727   NaN  21.453287
# 270728   NaN  21.453287
# 270729   NaN  17.361111
# 270730   NaN  17.361111
# 270731   NaN  20.281233
# 270732   NaN  20.281233
# 270733   NaN  24.524346
# 270734   NaN  15.780836
# 270738   NaN  21.967120
# 270739   NaN  21.967120
# 270740   NaN  19.044321
# 270741   NaN  24.456063
# 270742   NaN  20.544193
# 270743   NaN  20.544193
# 270744   NaN  20.324438
# 270745   NaN  20.324438
# 270746   NaN  18.253110
# 270747   NaN  23.875115
# 270748   NaN  18.467221
# 270749   NaN  18.467221
# 270751   NaN  16.423650
# 270753   NaN  20.515086
# 270754   NaN  20.515086
# 270759   NaN  23.068051
# 270760   NaN  16.955017
# 270762   NaN  24.888889
# 270763   NaN  24.888889
# 270765   NaN  21.799308
# 270766   NaN  24.489796
#
# [205911 rows x 18 columns]

# %%
bmi_df = bmi_df_copy

# %%
# Picking out the range of years we want to observe
bmi_df_1900 = bmi_df[(bmi_df['Year'] >=1900) & (bmi_df['Year'] <= 1916)]
bmi_df_2000 = bmi_df[(bmi_df['Year'] >=2000) & (bmi_df['Year'] <= 2016)]

# %%
# Looking at the kde
plt.figure(figsize = (15,10))
sns.distplot(bmi_df_1900['BMI'], label = '1900-1916')
sns.distplot(bmi_df_2000['BMI'], label = '2000-2016')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('BMI', fontsize=20)
plt.ylabel('Probability', fontsize=20)
plt.title('KDE Plot for BMI Populations 100 Years Apart', fontsize=20)
plt.legend(fontsize=20)

# %%
# Looking at histograms
plt.figure(figsize = (15,10))
sns.distplot(bmi_df_1900['BMI'], label = '1900-1916', kde=False)
sns.distplot(bmi_df_2000['BMI'], label = '2000-2016', kde=False)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('BMI', fontsize=20)
plt.ylabel('Counts', fontsize=20)
plt.title('KDE Plot for BMI Populations 100 Years Apart', fontsize=20)
plt.legend(fontsize=20)

# %% [markdown]
# There is overwhelmingly more of the 2000-2016 data. To exercise a basic z-test, we have decided to take random samples of the 2000-2016 population and run our hypothesis tests against the known 1900-1916 population. We will be using a z-test with our null hypothesis to mean there is no change between the BMI populations, and the alternative hypothesis to mean there is a difference between the populations. Using standard $\alpha = 0.05$.
#
# \begin{align}
# H_0 &: \mathrm{There\ is\ no\ difference\ in\ BMI\ between\ populations}\\
# H_1 &: \mathrm{There\ is\ a\ difference}\\
# \end{align}

# %%
# How much more data is there
len(bmi_df_2000)-len(bmi_df_1900)
# Out:
# 82469

# %%
len(bmi_df_1900)
# Out:
# 1308

# %%
pop_mean1900 = bmi_df_1900['BMI'].mean()
pop_std1900 = bmi_df_1900['BMI'].std()
pop_mean1900
# Out:
# 23.26618493684122

# %%
0.05*10000
# Out:
# 500.0

# %% [markdown]
# # Test
#
# We decided to run this z-test 10,000 times and observe all the resulting p-values. If the two populations are one in the same, we would expect a p-value of 0.05 to come up 5% of the time or around 500 times.

# %%
p_values = []
sample_of_thirty_2000_se = pop_std1900/np.sqrt(len(sample_of_thirty_2000))
for n in range(10000):
    sample_of_thirty_2000 = bmi_df_2000['BMI'].sample(n=30)
    sample_of_thirty_2000_mean = np.mean(sample_of_thirty_2000)
    z = (sample_of_thirty_2000_mean - pop_mean1900)/sample_of_thirty_2000_se

    
    p_values.append(1 - stats.norm.sf(z))

# %%
p_arr = np.array(p_values)

# %%
len(p_arr[p_arr<0.05])/10000
# Out:
# 0.2339

# %% [markdown]
# # Result:
# We observed a p-value less than our $\alpha$ nearly a quarter of the time. From this simulation, we reject the null hypothesis. These two populations are different. The BMI of the athletes has changed over the 100 years!
#
# Since we have the actual populations, we can observe them and check our statistics. These are plotted below.

# %%
BMI_dist_1900 = np.random.normal(pop_mean1900, pop_std1900, len(bmi_df_1900))
BMI_dist_2000 = np.random.normal(bmi_df_2000['BMI'].mean(), bmi_df_2000['BMI'].std(), len(bmi_df_2000))

fig = plt.figure(figsize = (15, 10))
sns.distplot(BMI_dist_1900, label = '1900-1916', kde=True)
sns.distplot(BMI_dist_2000, label = '2000-2016', kde=True)
plt.title('Mean BMI Distributions', fontsize = 20)
plt.xlabel('BMI', fontsize = 20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 20})

# %% [markdown]
# A bit hard to see, but there is a slight difference in the mean of these two curves. Since we have the whole population of both categories, we can just check to see if our statistics is correct.

# %%
bmi_df_1900['BMI'].mean()
# Out:
# 23.26618493684122

# %%
bmi_df_2000['BMI'].mean()
# Out:
# 22.779453669166937

# %% [markdown]
# Yep, they're different.
#
# Looks like athletes have a lower BMI 100 years later. Why is that? Have world athletes gotten smaller over time?
#
# A little bit of investigation of the data frame shows that, although there are female athletes in the 1900-1916 population, they are missing data about their height and weight.
#
# The 2000-2016 has overwhemingly more female athletes in it. So we will run the same hypothesis tests again, one for the males and the other for the females.

# %%
# Showing the distribution of females in the olympics over time
female_count = df[df['Sex']=='F']['Year'].value_counts().sort_index()
female_count
# Out:
# 1900      33
# 1904      16
# 1906      11
# 1908      47
# 1912      87
# 1920     134
# 1924     261
# 1928     437
# 1932     369
# 1936     549
# 1948     761
# 1952    1680
# 1956    1136
# 1960    1730
# 1964    1752
# 1968    2193
# 1972    2605
# 1976    2605
# 1980    2186
# 1984    2983
# 1988    4222
# 1992    5164
# 1994    1105
# 1996    4998
# 1998    1384
# 2000    5418
# 2002    1582
# 2004    5531
# 2006    1757
# 2008    5793
# 2010    1847
# 2012    5791
# 2014    2023
# 2016    6203
# Name: Year, dtype: int64

# %%
bmi_df_1900[bmi_df_1900['Sex'] == 'F'] # no bmi data found for female athletes
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal, region, notes, BMI]
# Index: []

# %%
bmi_df[bmi_df['Sex']=='F']['Year'].value_counts().sort_index() # here's what we do have
# Out:
# 1920       1
# 1924       7
# 1928      56
# 1932      57
# 1936      88
# 1948     137
# 1952     417
# 1956     525
# 1960    1516
# 1964    1643
# 1968    2169
# 1972    2491
# 1976    2462
# 1980    2049
# 1984    2885
# 1988    4001
# 1992    4079
# 1994    1023
# 1996    4234
# 1998    1350
# 2000    5373
# 2002    1555
# 2004    5521
# 2006    1753
# 2008    5716
# 2010    1837
# 2012    5631
# 2014    1920
# 2016    6101
# Name: Year, dtype: int64

# %%
# Performing the same hypothesis test, but on the male athletes only
male2000_df = bmi_df_2000[bmi_df_2000['Sex']=='M']
male2000_df['Year'].value_counts()
# Out:
# 2000    8286
# 2004    7856
# 2008    7650
# 2016    7310
# 2012    6857
# 2014    2753
# 2006    2612
# 2010    2541
# 2002    2505
# Name: Year, dtype: int64

# %%
p_values = []

for i in range(10000):
    sample_m_2000 = male2000_df['BMI'].sample(n=30)
    sample_m_2000_mean = np.mean(sample_m_2000)
    sample_m_2000_se = pop_std1900/np.sqrt(len(sample_m_2000))
    z = (sample_m_2000_mean - pop_mean1900)/sample_m_2000_se
    p = 1 - stats.norm.sf(z)
    p_values.append(p)

# %%
p_values_arr = np.array(p_values)
len(p_values_arr[p_values_arr < 0.05])
# Out:
# 21

# %% [markdown]
# # Result
# Out of 10,000 trials, we attained a p-value of less than 0.05 only 21 times. 9,978 times out of 10,000 our p-value was greater than 0.05. Based on this evidence, we failed to reject the null hypothesis, which suggests that the BMI has not changed for male athletes in the Olympics over the last 100 years.

# %%
# Again, we have the populations and can just check to confirm our statistics
male2000_df['BMI'].mean()
# Out:
# 23.787136059578533

# %%
bmi_df_1900['BMI'].mean() # No statistically significant difference
# Out:
# 23.26618493684122

# %% [markdown]
# # Have the Female Athletes BMI Changed Over Time?

# %% [markdown]
# #  Does the US perform better when hosting the Olympics or when abroad?
# We will observe the top 5 sports in which the US competes in at home and abroad and do an ANOVA test to see if there is any signficant difference in the gold medals won. To do this, we will judge the top 5 categories by the number of gold medals won. That is for the top 5 events, we will count the number of gold medals won at home in the first column and the number of gold medals won away in the second column. We will then standardize the gold medal count by dividing by the number of events competed in. On this data frame, we then perform an ANOVA test.
#
# Since the US has participated in the Olympics away far more times than at home, we randomly sample the away data to pick 5 cities for comparison.

# %%
host_usa_df = bmi_df[(bmi_df['City']=='Atlanta') 
                            | (bmi_df['City']=='Los Angeles') | (bmi_df['City']=='Salt Lake City')
                            | (bmi_df['City']=='St. Louis') | (bmi_df['City']=='Lake Placid') 
                            | (bmi_df['City']=='Squaw Valley')]

# %%
host_usa_df['City'].value_counts()
# Out:
# Atlanta           11816
# Los Angeles        9352
# Salt Lake City     4060
# Lake Placid        1417
# Squaw Valley        512
# St. Louis           119
# Name: City, dtype: int64

# %%
usa_home = host_usa_df[host_usa_df['region']=='USA']

# %%
guest_usa_df = bmi_df[(bmi_df['City']!='Atlanta') 
                            & (bmi_df['City']!='Los Angeles') & (bmi_df['City']!='Salt Lake City')
                            & (bmi_df['City']!='St. Louis') & (bmi_df['City']!='Lake Placid') 
                            & (bmi_df['City']!='Squaw Valley')]
guest_usa_df['City'].value_counts()
# Out:
# London                    13768
# Sydney                    13659
# Athina                    13618
# Rio de Janeiro            13411
# Beijing                   13366
# Seoul                     11591
# Barcelona                 10310
# Munich                     9838
# Mexico City                8396
# Montreal                   8261
# Roma                       7521
# Tokyo                      7368
# Moskva                     6843
# Sochi                      4673
# Vancouver                  4378
# Torino                     4365
# Nagano                     3518
# Lillehammer                2971
# Albertville                2783
# Innsbruck                  2645
# Melbourne                  2153
# Calgary                    2018
# Sarajevo                   1951
# Helsinki                   1914
# Grenoble                   1801
# Sapporo                    1635
# Berlin                      827
# Stockholm                   657
# Amsterdam                   622
# Paris                       614
# Antwerpen                   428
# Cortina d'Ampezzo           334
# Sankt Moritz                146
# Oslo                        144
# Garmisch-Partenkirchen       69
# Chamonix                     39
# Name: City, dtype: int64

# %%
usa_away = guest_usa_df[guest_usa_df['region']=='USA']

# %%
usa_home['Medal'].value_counts()
# Out:
# Gold      452
# Silver    249
# Bronze    132
# Name: Medal, dtype: int64

# %%
usa_away['Medal'].value_counts()
# Out:
# Gold      1663
# Silver    1037
# Bronze     850
# Name: Medal, dtype: int64

# %%
usa_away['City'].sample(n=6) # originally gave cities found below

# %%
usa_away_sample = usa_away[(usa_away['City'] == 'Seoul') | (usa_away['City'] == 'Sarajevo')|
                           (usa_away['City'] == 'Vancouver')| (usa_away['City'] == 'Paris')|
                           (usa_away['City'] == 'Athina') | (usa_away['City'] == 'Sydney')]

# %%
usa_away_sports = usa_away[(usa_away['Sport']=='Swimming') | (usa_away['Sport']== 'Athletics') | 
                           (usa_away['Sport'] == 'Basketball')
                           | (usa_away['Sport']== 'Rowing') | (usa_away['Sport']== 'Football')]

usa_away_sports['Sport'].value_counts()
# Out:
# Athletics     2555
# Swimming      1143
# Rowing         564
# Basketball     293
# Football       180
# Name: Sport, dtype: int64

# %%
usa_home_sports = usa_home[(usa_home['Sport']=='Swimming') | (usa_home['Sport']== 'Athletics') | 
                           (usa_home['Sport'] == 'Basketball')
                           | (usa_home['Sport']== 'Rowing') | (usa_home['Sport']== 'Football')]
usa_home_sports['Sport'].value_counts()
# Out:
# Athletics     423
# Swimming      179
# Rowing        113
# Basketball     48
# Football       38
# Name: Sport, dtype: int64

# %%
usa_away_sports[usa_away_sports['Medal']=='Gold']['Sport'].value_counts()
# Out:
# Swimming      467
# Athletics     427
# Basketball    233
# Rowing         88
# Football       51
# Name: Sport, dtype: int64

# %%
usa_home_sports[usa_home_sports['Medal']=='Gold']['Sport'].value_counts()
# Out:
# Athletics     104
# Swimming       99
# Basketball     48
# Rowing         22
# Football       15
# Name: Sport, dtype: int64

# %%
usa_away_sports_sample = usa_away_sports.sample(n=801)

# %%
anova = pd.DataFrame(usa_home_sports[usa_home_sports['Medal']=='Gold']['Sport'].value_counts())

# %%
anova.columns = ['usa_home']

# %%
anova['usa_away'] = usa_away_sports_sample[usa_away_sports['Medal']=='Gold']['Sport'].value_counts()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
len(usa_home['Sport'].value_counts())
# Out:
# 48

# %%
len(usa_away['Sport'].value_counts())
# Out:
# 54

# %%
anova['usa_home'] = anova['usa_home']/48

# %%
anova['usa_away'] = anova['usa_away']/54

# %%
anova
# Out:
#             usa_home  usa_away
# Athletics   2.166667  1.240741
# Swimming    2.062500  1.444444
# Basketball  1.000000  1.074074
# Rowing      0.458333  0.388889
# Football    0.312500  0.148148

# %%
x1_bar = anova['usa_home'].mean()
x2_bar = df_anova['usa_away'].mean()

x_2bar = (x1_bar + x2_bar)/2

# %%
SST_to_sum = []
for number in range(5):
    SST_to_sum.append((anova.iloc[number][0]-x_2bar)**2)
    SST_to_sum.append((anova.iloc[number][1]-x_2bar)**2)
    
SST = sum(SST_to_sum)
SST
# Out:
# 58762.51029449586

# %%
SSW = (104-x1_bar)**2 + (99 - x1_bar)**2 + (48-x1_bar)**2 + (22-x1_bar)**2 + (15-x1_bar)**2 +\
      (74-x2_bar)**2 + (94-x2_bar)**2 + (32-x2_bar)**2 + (13-x2_bar)**2 + (8-x2_bar)**2 
SSW
# Out:
# 89210.13888888888

# %%
SSB = 6*(x1_bar-x_2bar)**2 + 6*(x2_bar-x_2bar)**2

# %%
m = 2
n = 5

# %%
F_stat = ((SSB/(m-1))/((SSW/(m*(n-1)))))
F_stat
# Out:
# 6.294926043844668

# %% [markdown]
# ## Critical F value is 5.79
#
# # Our F stat is 6.29
#
# Since our F stat is above the critical value, we reject the null hypothesis. This suggests performance is the better for the U.S. when hosting the olympics.
